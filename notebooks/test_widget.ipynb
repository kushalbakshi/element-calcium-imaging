# %%
import os

# change to the upper level folder to detect dj_local_conf.json
if os.path.basename(os.getcwd()) == "notebooks":
    os.chdir("..")

import datajoint as dj
from element_calcium_imaging.plotting.draw_rois import draw_rois

# %%
dj.config["database.host"] = "db.datajoint.com"
dj.config["database.user"] = "vathes-team-worker"
dj.config["database.password"] = "g2d6m3mPUnfR73T8+JPXtA=="
dj.config["custom"]["imaging_root_data_dir"] = "C:/Users/kusha/dj-elements/element-calcium-imaging/example_data"

# %%
draw_rois("vathes-team_devlab_kushal_").run_server()
# Out:
# [2024-04-09 00:13:55,766][INFO]: Connecting vathes-team-worker@db.datajoint.com:3306
# [2024-04-09 00:13:56,366][INFO]: Connected vathes-team-worker@db.datajoint.com:3306
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# [2024-04-09 00:14:05,891][INFO]: Generating figure.
# [2024-04-09 00:14:20,353][INFO]: Creating Masks.
# Masks created
# Images shape: (3000, 512, 512)
# [2024-04-09 00:14:21,714][INFO]: Inserting 1 masks into the database.
# [2024-04-09 00:14:21,717][INFO]: Inserting 1 traces into the database.
# Mask ID: [1275]
